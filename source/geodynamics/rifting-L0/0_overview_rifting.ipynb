# %% [markdown]
# <img src="../../../assets/education-gem-notebooks_icon.png" alt="icon"  align="center" width="10%" >
#
#
# <tr>
#   <td style="width: 20%" align="center"> </td>
#   <td> <h1 style="text-align: center;">CIG-GEM Education Notebook</h1>
#         <h1 style="text-align: center;">Rifting Module</h1>
#         <h2 style="text-align: center;">Foundational Level (L0)</h2>
#         <h3 style="text-align: center;">v0.1</h3>  </td>
# </tr>
#
#
# <h4 style="margin-left:20px"><i> Authors: A. Saxena and J. Naliboff with contributions from the CIG Education Working Group </i></h4>
# <br>
#
# <img src="../../../assets/cig-logo.png" alt="cig icon" width="10%">
#
# [![License: GPLv3](https://img.shields.io/badge/License-GPLv3-blue)](LICENSE)
#
# ***

# %% [markdown]
# ## Description<a name="label:desc"></a>
#
# An introduction to tectonic processes governing continental rifting and how to develop numerical models to investigate this process using the geodynamic modeling software ASPECT.
#
# ## Learning objectives
#
# ### Scientific
# Upon completion of this module you would be familiar with:
# - Forces governing rifting
# - Computing the lithospheric strength envelope
# - Rift weakening and localization
#
# ### Technical
# Upon completion of this module you will be able to:
# - Run ASPECT from the command line
# - Understand the basic layout of the model simulation file
# - Visualize model simulation results using Python
#
# ## Dependencies
# - Python (> version 3.3) with the following libraries installed:
#   * Matplotlib
#   * NumPy
#   * PyVista
#
# - ASPECT (> version 3.0) installed locally or using the ASPECT Jupyter notebook on the CIG HUBZero platform [here](https://geodynamics.org/resources/tools)

# %% [markdown]
# # Table of Contents
#
# - [Summary](#label:desc)
#
# - [Physical mechanism of rifting](./1_physical_mechanism_rifting.ipynb)
#
# - [Lithospheric strength profile](./2_lithospheric_strength_profile.ipynb)
#
# - [ASPECT.prm file description](./3_rifting_prm_description.ipynb)
#
# - [Plot model simulation results](4_plot_model_results.ipynb)

# %% [markdown]
#    &nbsp;<div style="text-align: right">
#     &rarr; <b>NEXT: [Physical mechanism of rifting](./1_physical_mechanism_rifting.ipynb) </b> <a href=""></a> &nbsp;&nbsp;
#      <img src="../../../assets/education-gem-notebooks_icon.png" alt="icon"  width="4%">
#   </div>
