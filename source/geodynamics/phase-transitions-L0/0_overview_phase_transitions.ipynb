# %% [markdown]
# <br>
#
# <table style="width: 70%; border-collapse: collapse; border: none; margin-left:60px">
#   <tr>
#     <td style="width: 20%" align="center"> <img src="../../../assets/education-gem-notebooks_icon.png" alt="icon"  width="80%" ></td>
#     <td> <h1 style="text-align: center;"> CIG-GEM Education Notebook</h1>
#          <h1 style="text-align: center;">Phase Transitions Module</h1>
#          <h2 style="text-align: center;">Foundational Level (L0)</h2>
#          <h3 style="text-align: center;">v0.1</h3>  </td>
#   </tr>
# </table>
#
# <h4 style="margin-left:20px"><i> Authors: J. Dannberg, A. Saxena with contributions from the CIG Education Working Group </i></h4>
# <br>
# <img src="../../../assets/cig-logo.png" alt="cig icon" width="10%">
#
# [![License: GPLv3](https://img.shields.io/badge/License-GPLv3-blue)](LICENSE)
#
# ***

# %% [markdown]
# ## Description<a name="label:desc"></a>
#
# An introduction to mineral phase transitions, seismological observations of phase changes, and their dynamic implications on plumes and slabs.
#
# ## Learning objectives
#
# ### Scientific
# Upon completion of this module you would be familiar with:
# - Mineral phase transitions in the Earth
# - Seismic observations of phase transitions
# - Clapeyron slopes
# - Effect of the Clapeyron slope on a rising plume and subducting slab
#
# ### Technical
# Upon completion of this module you will be able to:
# - Run ASPECT from the command line
# - Understand the basic layout of the model simulation file
# - Visualize model simulation results
# - Use Python for writing basic plotting routines
#
# ## Dependencies
# - Python (> version 3.3) with the following libraries installed:
#   * SciPy
#   * Matplotlib
#   * NumPy
#   * PyVista
#   * BurnMan
#
# - ASPECT (> version 2.0) installed locally or using the ASPECT Jupyter notebook on the CIG HUBZero platform [here](https://geodynamics.org/resources/tools)

# %% [markdown]
# # Table of contents
#
#
# - [Summary](#label:desc)
#
# - [Observations of phase transitions](./1_phase_transition_observations.ipynb)
#
# - [Clapeyron slope](./2_clapeyron_slope.ipynb)
#
# - [Modeling phase transitions](./3_modeling_phase_transitions.ipynb)
#
# - [Plotting effects of phase transition](./4_plotting_effects_of_phase_transition.ipynb)

# %% [markdown]
#  &nbsp;<div style="text-align: right">
#     &rarr; <b>NEXT: [Observations of phase transitions](./1_phase_transition_observations.ipynb) </b> <a href=""></a> &nbsp;&nbsp;
#      <img src="../../../assets/education-gem-notebooks_icon.png" alt="icon" width="4%">
#   </div>
