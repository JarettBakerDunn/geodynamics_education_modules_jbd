# %% [markdown]
# ## Running the models
#
# For understanding the effects of both plume and slab dynamics at phase transition, we will run the corresponding ASPECT parameter file as described in the previous section.

# %% [markdown]
# > In the cells below, it is assumed that the ASPECT directory is installed system-wide or that you are using ASPECT using the provided binder file. If not, modify the ASPECT executable to the location where it is installed.

# %%
! aspect-release prm_files/plume.prm
# Out:
# -----------------------------------------------------------------------------
# --                             This is ASPECT                              --
# -- The Advanced Solver for Planetary Evolution, Convection, and Tectonics. --
# -----------------------------------------------------------------------------
# --     . version 3.1.0-pre
# --     . using deal.II 9.7.1
# --     .       with 32 bit indices
# --     .       with vectorization level 1 (SSE2, 2 doubles, 128 bits)
# --     . using Trilinos 16.2.0
# --     . using p4est 2.8.7
# --     . using Geodynamic World Builder 1.0.0
# --     . running in OPTIMIZED mode
# --     . running with 1 MPI process
# -----------------------------------------------------------------------------
#
# -----------------------------------------------------------------------------
# -- For information on how to cite ASPECT, see:
# --   https://aspect.geodynamics.org/citing.html?ver=3.1.0-pre&dg=1&mf=1&sha=f56842eca&src=code
# -----------------------------------------------------------------------------
# Number of active cells: 128 (on 4 levels)
# Number of degrees of freedom: 2,988 (1,122+153+561+1,152)
#
# *** Timestep 0:  t=0 years, dt=0 years
#    Solving temperature system... 0 iterations.
#    Solving plume system ... 0 iterations.
#    Solving Stokes system (GMG)... 8+0 iterations.
#
# Number of active cells: 146 (on 5 levels)
# Number of degrees of freedom: 3,457 (1,310+178+655+1,314)
#
# *** Timestep 0:  t=0 years, dt=0 years
#    Solving temperature system... 0 iterations.
#    Solving plume system ... 0 iterations.
#    Solving Stokes system (GMG)... 9+0 iterations.
#
#    Postprocessing:
#      Writing graphical output: plume/solution/solution-00000
#      RMS, max velocity:        0.00615 m/year, 0.0507 m/year
#      Temperature min/avg/max:  1560 K, 1575 K, 1674 K
#
# *** Timestep 1:  t=589981 years, dt=589981 years
#    Solving temperature system... 10 iterations.
#    Solving plume system ... 4 iterations.
#    Solving Stokes system (GMG)... 10+0 iterations.
#
#    Postprocessing:
#      Writing graphical output: plume/solution/solution-00001
#      RMS, max velocity:        0.00752 m/year, 0.064 m/year
#      Temperature min/avg/max:  1560 K, 1575 K, 1674 K
#
# *** Timestep 2:  t=1.04974e+06 years, dt=459761 years
#    Solving temperature system... 9 iterations.
#    Solving plume system ... 3 iterations.
#    Solving Stokes system (GMG)... 9+0 iterations.
#
#    Postprocessing:
#      Writing graphical output: plume/solution/solution-00002
#      RMS, max velocity:        0.00959 m/year, 0.081 m/year
#      Temperature min/avg/max:  1560 K, 1575 K, 1674 K
#
# *** Timestep 3:  t=1.40853e+06 years, dt=358784 years
#    Solving temperature system... 10 iterations.
#    Solving plume system ... 3 iterations.
#    Solving Stokes system (GMG)... 9+0 iterations.
#
#    Postprocessing:
#      Writing graphical output: plume/solution/solution-00003
#      RMS, max velocity:        0.0126 m/year, 0.0937 m/year
#      Temperature min/avg/max:  1560 K, 1575 K, 1674 K
#
# *** Timestep 4:  t=1.72456e+06 years, dt=316029 years
#    Solving temperature system... 10 iterations.
#    Solving plume system ... 3 iterations.
#    Solving Stokes system (GMG)... 9+0 iterations.
#
#    Postprocessing:
#      Writing graphical output: plume/solution/solution-00004
#      RMS, max velocity:        0.0165 m/year, 0.101 m/year
#      Temperature min/avg/max:  1551 K, 1575 K, 1674 K
#
# *** Timestep 5:  t=2.02435e+06 years, dt=299798 years
#    Solving temperature system... 10 iterations.
#    Solving plume system ... 3 iterations.
#    Solving Stokes system (GMG)... 9+0 iterations.
#
#    Postprocessing:
#      Writing graphical output: plume/solution/solution-00005
#      RMS, max velocity:        0.0211 m/year, 0.114 m/year
#      Temperature min/avg/max:  1552 K, 1575 K, 1684 K
#
# Number of active cells: 152 (on 5 levels)
# Number of degrees of freedom: 3,595 (1,362+184+681+1,368)
#
# *** Timestep 6:  t=2.295e+06 years, dt=270645 years
#    Solving temperature system... 10 iterations.
#    Solving plume system ... 4 iterations.
#    Solving Stokes system (GMG)... 10+0 iterations.
#
#    Postprocessing:
#      Writing graphical output: plume/solution/solution-00006
#      RMS, max velocity:        0.0278 m/year, 0.139 m/year
#      Temperature min/avg/max:  1553 K, 1575 K, 1693 K
#
# *** Timestep 7:  t=2.51815e+06 years, dt=223148 years
#    Solving temperature system... 18 iterations.
#    Solving plume system ... 5 iterations.
#    Solving Stokes system (GMG)... 10+0 iterations.
#
#    Postprocessing:
#      Writing graphical output: plume/solution/solution-00007
#      RMS, max velocity:        0.0285 m/year, 0.142 m/year
#      Temperature min/avg/max:  1558 K, 1575 K, 1693 K
#
# *** Timestep 8:  t=2.73609e+06 years, dt=217944 years
#    Solving temperature system... 9 iterations.
#    Solving plume system ... 4 iterations.
#    Solving Stokes system (GMG)... 6+0 iterations.
#
#    Postprocessing:
#      Writing graphical output: plume/solution/solution-00008
#      RMS, max velocity:        0.0291 m/year, 0.144 m/year
#      Temperature min/avg/max:  1552 K, 1575 K, 1693 K
#
# *** Timestep 9:  t=2.95067e+06 years, dt=214575 years
#    Solving temperature system... 9 iterations.
#    Solving plume system ... 4 iterations.
#    Solving Stokes system (GMG)... 7+0 iterations.
#
#    Postprocessing:
#      Writing graphical output: plume/solution/solution-00009
#      RMS, max velocity:        0.0298 m/year, 0.147 m/year
#      Temperature min/avg/max:  1544 K, 1575 K, 1692 K
#
# *** Timestep 10:  t=3.16204e+06 years, dt=211374 years
#    Solving temperature system... 9 iterations.
#    Solving plume system ... 4 iterations.
#    Solving Stokes system (GMG)... 7+0 iterations.
#
#    Postprocessing:
#      Writing graphical output: plume/solution/solution-00010
#      RMS, max velocity:        0.0308 m/year, 0.15 m/year
#      Temperature min/avg/max:  1540 K, 1575 K, 1692 K
#
# Number of active cells: 152 (on 5 levels)
# Number of degrees of freedom: 3,582 (1,354+183+677+1,368)
#
# *** Timestep 11:  t=3.36968e+06 years, dt=207639 years
#    Solving temperature system... 9 iterations.
#    Solving plume system ... 4 iterations.
#    Solving Stokes system (GMG)... 9+0 iterations.
#
#    Postprocessing:
#      Writing graphical output: plume/solution/solution-00011
#      RMS, max velocity:        0.0211 m/year, 0.0909 m/year
#      Temperature min/avg/max:  1539 K, 1575 K, 1691 K
#
# *** Timestep 12:  t=3.71991e+06 years, dt=350231 years
#    Solving temperature system... 32 iterations.
#    Solving plume system ... 6 iterations.
#    Solving Stokes system (GMG)... 9+0 iterations.
#
#    Postprocessing:
#      Writing graphical output: plume/solution/solution-00012
#      RMS, max velocity:        0.028 m/year, 0.121 m/year
#      Temperature min/avg/max:  1560 K, 1576 K, 1687 K
#
# *** Timestep 13:  t=3.9782e+06 years, dt=258292 years
#    Solving temperature system... 11 iterations.
#    Solving plume system ... 4 iterations.
#    Solving Stokes system (GMG)... 8+0 iterations.
#
#    Postprocessing:
#      Writing graphical output: plume/solution/solution-00013
#      RMS, max velocity:        0.0305 m/year, 0.133 m/year
#      Temperature min/avg/max:  1566 K, 1576 K, 1687 K
#
# *** Timestep 14:  t=4.21311e+06 years, dt=234909 years
#    Solving temperature system... 10 iterations.
#    Solving plume system ... 4 iterations.
#    Solving Stokes system (GMG)... 8+0 iterations.
#
#    Postprocessing:
#      Writing graphical output: plume/solution/solution-00014
#      RMS, max velocity:        0.0317 m/year, 0.138 m/year
#      Temperature min/avg/max:  1567 K, 1576 K, 1688 K
#
# *** Timestep 15:  t=4.43854e+06 years, dt=225429 years
#    Solving temperature system... 9 iterations.
#    Solving plume system ... 4 iterations.
#    Solving Stokes system (GMG)... 7+0 iterations.
#
#    Postprocessing:
#      Writing graphical output: plume/solution/solution-00015
#      RMS, max velocity:        0.0316 m/year, 0.135 m/year
#      Temperature min/avg/max:  1567 K, 1576 K, 1689 K
#
# Number of active cells: 176 (on 5 levels)
# Number of degrees of freedom: 4,136 (1,562+209+781+1,584)
#
# *** Timestep 16:  t=4.67146e+06 years, dt=232925 years
#    Solving temperature system... 10 iterations.
#    Solving plume system ... 4 iterations.
#    Solving Stokes system (GMG)... 8+0 iterations.
#
#    Postprocessing:
#      Writing graphical output: plume/solution/solution-00016
#      RMS, max velocity:        0.0428 m/year, 0.167 m/year
#      Temperature min/avg/max:  1566 K, 1576 K, 1689 K
#
# *** Timestep 17:  t=4.85361e+06 years, dt=182148 years
#    Solving temperature system... 16 iterations.
#    Solving plume system ... 5 iterations.
#    Solving Stokes system (GMG)... 8+0 iterations.
#
#    Postprocessing:
#      Writing graphical output: plume/solution/solution-00017
#      RMS, max velocity:        0.0423 m/year, 0.166 m/year
#      Temperature min/avg/max:  1566 K, 1576 K, 1687 K
#
# *** Timestep 18:  t=5e+06 years, dt=146388 years
#    Solving temperature system... 9 iterations.
#    Solving plume system ... 4 iterations.
#    Solving Stokes system (GMG)... 6+0 iterations.
#
#    Postprocessing:
#      Writing graphical output: plume/solution/solution-00018
#      RMS, max velocity:        0.042 m/year, 0.166 m/year
#      Temperature min/avg/max:  1565 K, 1576 K, 1686 K
#
# Termination requested by criterion: end time
#
#
# +----------------------------------------------+------------+------------+
# | Total wallclock time elapsed since start     |     0.869s |            |
# |                                              |            |            |
# | Section                          | no. calls |  wall time | % of total |
# +----------------------------------+-----------+------------+------------+
# | Assemble Stokes system rhs       |        20 |    0.0682s |       7.8% |
# | Assemble composition system      |        20 |     0.171s |        20% |
# | Assemble temperature system      |        20 |    0.0813s |       9.4% |
# | Build Stokes preconditioner      |        20 |    0.0073s |      0.84% |
# | Build composition preconditioner |        20 |    0.0422s |       4.9% |
# | Build temperature preconditioner |        20 |    0.0134s |       1.5% |
# | Initialization                   |         1 |     0.105s |        12% |
# | Postprocessing                   |        19 |    0.0779s |         9% |
# | Refine mesh structure, part 1    |         4 |   0.00396s |      0.46% |
# | Refine mesh structure, part 2    |         4 |   0.00339s |      0.39% |
# | Setup dof systems                |         5 |    0.0349s |         4% |
# | Setup initial conditions         |         2 |    0.0109s |       1.3% |
# | Setup matrices                   |         5 |    0.0346s |         4% |
# | Solve Stokes system              |        20 |     0.136s |        16% |
# | Solve composition system         |        20 |    0.0193s |       2.2% |
# | Solve temperature system         |        20 |    0.0102s |       1.2% |
# +----------------------------------+-----------+------------+------------+
#
# -- Total wallclock time elapsed including restarts: 1s
# -----------------------------------------------------------------------------
# -- For information on how to cite ASPECT, see:
# --   https://aspect.geodynamics.org/citing.html?ver=3.1.0-pre&dg=1&mf=1&sha=f56842eca&src=code
# -----------------------------------------------------------------------------

# %%
# %%capture
! aspect-release prm_files/slab.prm

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Note:</b> The provided .prm files are configured to run on a single node in a reasonable time, but a finer mesh is recommended that can resolve the effects of phase transition on subducting slab and a rising plume. To do this, increase `set Initial global refinement` to a higher value. The plots below use 5 as the global refinement level.
# </div>

# %%
# Load the relevant libraries
import pyvista as pv
import glob
from IPython.display import HTML

# %%
def plot_deformation(output_dir, field, label, gif_file, cmap='RdBu'):
    '''
    Process a series of VTU files in the given output directory, returning the 'field'
    data for plotting.
    Inputs:
    -----------
    output_dir : str
        Path to the folder containing solution VTU files (expected in solution/solution-*.vtu)
    field : str
        Name of the field we want to look at in the solution
    label : str
        Label for the field being plotted
    '''

    solution_file_names = sorted(glob.glob(output_dir + 'solution/solution-*.pvtu'))

    mesh = pv.read(solution_file_names[0])

    plotter = pv.Plotter()

    # Create the first frame
    plotter.add_mesh(mesh, scalars=field, show_scalar_bar=False)
    plotter.add_axes()

    # We know that the model is XY plane so the following
    # lines just sets up the camera
    plotter.view_xy()
    plotter.camera.roll = 0
    plotter.camera.parallel_projection = True

    plotter.open_gif(gif_file, fps=4)

    # Update function for each frame
    def update(frame):
        frame_int = int(frame)
        new_mesh = pv.read(solution_file_names[frame_int])
        plotter.add_mesh(new_mesh, scalars=field, cmap='RdBu', \
                         scalar_bar_args={"vertical": True, "title": label})

         # Add a slice at y = 340 km (or 660 km from the top)
        slice_position = 340e3
        slice_mesh = mesh.slice(normal='y', origin=(0, slice_position, 0))
        plotter.add_mesh(slice_mesh, color='white', show_scalar_bar=False)

        plotter.add_text(f"Time step: {frame}", name="tstep")
        plotter.add_text(field,  position='upper_right', font_size=14)

    n_frames = len(solution_file_names)

    for i in range(n_frames):
        update(i)
        plotter.write_frame()

    plotter.close()

# %%
# Make sure that the compositional field in the function
# matches what we have specified in the ASPECT input files:
# 'plume' and 'subducting_crust'
plot_deformation('plume/', 'plume', 'Composition', 'images/plume.gif')
plot_deformation('slab/', 'subducting_crust', 'Composition', 'images/slab.gif')

# %%
# Now, you would have the gifs saved in the current directory
# this cell visualizes the model outputs side by side for
# comparison

HTML(f"""
<div style="display: flex; justify-content: center; align-items: center; gap: 10px;">
    <img src="{'./images/plume.gif'}" width="750">
    <img src="{'./images/slab.gif'}" width="750">
</div>
""")

# %% [markdown]
# In the cell above, you can see that both plume and slab stagnate, as expected, at around 660 km depth (marked by the white line). This is due to our chosen negative Clapeyron slope to represent the endothermic spinel–perovskite phase transition at this depth.

# %% [markdown]
# ### Exercises
#
# - Modify the Clapeyron slope to a positive value (e.g. 2 MPa/K in `Phase transition Clapeyron slopes`) and rerun the model. What changes do you observe in the plume and slab dynamics at 660 km depth?
#
# - Modify the density contrast of the plume/slab with the surrounding mantle (`Density differential for compositional field 1`) and rerun the model. Do you still observe stagnation at 660 km depth? How does the density contrast affect the dynamics?

# %% [markdown]
# ### Appendix:
#
# After the model successfully runs, you should see a terminal output like below:
#
# <div align="center">
# <img src='./images/terminal_output.png' width="500"/>
# </div>
#
# The plume model takes approximately 12 seconds  while the slab model takes 1.5 minutes on 6 cores with 13th Gen Intel Core i7 processor.
# Both models reach the linear and nonlinear solver tolerance.
