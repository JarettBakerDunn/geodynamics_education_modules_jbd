# %% [markdown]
# <br>
#
# <table style="width: 70%; border-collapse: collapse; border: none; margin-left:60px">
#   <tr>
#     <td style="width: 20%" align="center"> <img src="../../../assets/education-gem-notebooks_icon.png" alt="icon"  width="80%" ></td>
#     <td> <h1 style="text-align: center;"> CIG-GEM Education Notebook</h1>
#          <h1 style="text-align: center;">Melt Module</h1>
#          <h2 style="text-align: center;">Foundational Level (L0)</h2>
#          <h3 style="text-align: center;">v0.1</h3>  </td>
#   </tr>
# </table>
#
# <h4 style="margin-left:20px"><i> Authors: A. Saxena with contributions from the CIG Education Working Group </i></h4>
# <br>
# <img src="../../../assets/cig-logo.png" alt="cig icon" width="10%">
#
# [![License: GPLv3](https://img.shields.io/badge/License-GPLv3-blue)](LICENSE)
#
# ***

# %% [markdown]
# ## Description<a name="label:desc"></a>
#
# An introduction to melt generation and surface volcanism in context of a rising mantle plume.
#
# ## Learning objectives
#
# ### Scientific
# Upon completion of this module you would be familiar with:
# - Melting in different tectonic settings
# - Physical parameters that control plume ascension
# - Fractional melting and melt extraction
#
# ### Technical
# Upon completion of this module you will be able to:
# - Run ASPECT from the command line
# - Understand the basic layout of a model simulation file
# - Visualize model simulation results using Python
#
# ## Dependencies
# - Python (> version 3.3) with the following libraries installed:
#   * Matplotlib
#   * NumPy
#   * PyVista
#
# - ASPECT (> version 3.0) installed locally or using the ASPECT Jupyter notebook on the CIG HUBZero platform [here](https://geodynamics.org/resources/tools)

# %% [markdown]
# # Table of Contents
#
# - [Summary](#label:desc)
#
# - [Melt generation](./1_melt_generation.ipynb)
#
# - [Fractional crystallization](./2_fractional_crystallization.ipynb)
#
# - [Plume generation](./3_plume_generation.ipynb)
#
# - [Plot parameterized melting curves](./4_plot_parameterized_melting_curves.ipynb)
#
# - [ASPECT .prm file description](./5_melting_prm_description.ipynb)
#
# - [Plotting melt models](./6_plotting_melt_model.ipynb)

# %% [markdown]
#  &nbsp;<div style="text-align: right">
#     &rarr; <b>NEXT: [Melt generation](./1_melt_generation.ipynb) </b> <a href=""></a> &nbsp;&nbsp;
#      <img src="../../../assets/education-gem-notebooks_icon.png" alt="icon" width="4%">
#   </div>
